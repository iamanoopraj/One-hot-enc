# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

from sklearn.model_selection import GridSearchCV,RandomizedSearchCV

# %%
data = pd.read_csv('loan_approval_dataset.csv')

# %%
data.head()
# Out:
#    loan_id  no_of_dependents      education self_employed  income_annum  \
# 0        1                 2       Graduate            No       9600000
# 1        2                 0   Not Graduate           Yes       4100000
# 2        3                 3       Graduate            No       9100000
# 3        4                 3       Graduate            No       8200000
# 4        5                 5   Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17600000             22700000           8000000    Approved
# 1                  2200000              8800000           3300000    Rejected
# 2                  4500000             33300000          12800000    Rejected
# 3                  3300000             23300000           7900000    Rejected
# 4                  8200000             29400000           5000000    Rejected

# %%
data[data['education']=='Graduate']
# Out:
# Empty DataFrame
# Columns: [loan_id, no_of_dependents, education, self_employed, income_annum, loan_amount, loan_term, cibil_score, residential_assets_value, commercial_assets_value, luxury_assets_value, bank_asset_value, loan_status]
# Index: []

# %%
# df.columns
# df['education'].str.strip().unique()

# %%
df = data.copy()
for col in df.columns:
    if df[col].dtype=='O':
        df[col] = df[col].str.strip()

# %%
# Cleaning --> EDA --> train_test_split --> Feature Engg.(Encoding,scaling,etc)--> model train --> Tuning

# %%
df.head()
# Out:
#    loan_id  no_of_dependents     education self_employed  income_annum  \
# 0        1                 2      Graduate            No       9600000
# 1        2                 0  Not Graduate           Yes       4100000
# 2        3                 3      Graduate            No       9100000
# 3        4                 3      Graduate            No       8200000
# 4        5                 5  Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                 17600000             22700000           8000000    Approved
# 1                  2200000              8800000           3300000    Rejected
# 2                  4500000             33300000          12800000    Rejected
# 3                  3300000             23300000           7900000    Rejected
# 4                  8200000             29400000           5000000    Rejected

# %%
df.shape
# Out:
# (4269, 13)

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X.head()
# Out:
#    loan_id  no_of_dependents     education self_employed  income_annum  \
# 0        1                 2      Graduate            No       9600000
# 1        2                 0  Not Graduate           Yes       4100000
# 2        3                 3      Graduate            No       9100000
# 3        4                 3      Graduate            No       8200000
# 4        5                 5  Not Graduate           Yes       9800000
#
#    loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0     29900000         12          778                   2400000
# 1     12200000          8          417                   2700000
# 2     29700000         20          506                   7100000
# 3     30700000          8          467                  18200000
# 4     24200000         20          382                  12400000
#
#    commercial_assets_value  luxury_assets_value  bank_asset_value
# 0                 17600000             22700000           8000000
# 1                  2200000              8800000           3300000
# 2                  4500000             33300000          12800000
# 3                  3300000             23300000           7900000
# 4                  8200000             29400000           5000000

# %%
y.head()
# Out:
# 0    Approved
# 1    Rejected
# 2    Rejected
# 3    Rejected
# 4    Rejected
# Name: loan_status, dtype: object

# %%
X.shape
# Out:
# (4269, 12)

# %%
y.shape
# Out:
# (4269,)

# %%
4269*0.75
# Out:
# 3201.75

# %%
4269*0.25
# Out:
# 1067.25

# %%
X.drop('loan_id',axis=1,inplace=True)

# %%
# train_test
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.75)

# %%
df.head(11)
# Out:
#     loan_id  no_of_dependents     education self_employed  income_annum  \
# 0         1                 2      Graduate            No       9600000
# 1         2                 0  Not Graduate           Yes       4100000
# 2         3                 3      Graduate            No       9100000
# 3         4                 3      Graduate            No       8200000
# 4         5                 5  Not Graduate           Yes       9800000
# 5         6                 0      Graduate           Yes       4800000
# 6         7                 5      Graduate            No       8700000
# 7         8                 2      Graduate           Yes       5700000
# 8         9                 0      Graduate           Yes        800000
# 9        10                 5  Not Graduate            No       1100000
# 10       11                 4      Graduate           Yes       2900000
#
#     loan_amount  loan_term  cibil_score  residential_assets_value  \
# 0      29900000         12          778                   2400000
# 1      12200000          8          417                   2700000
# 2      29700000         20          506                   7100000
# 3      30700000          8          467                  18200000
# 4      24200000         20          382                  12400000
# 5      13500000         10          319                   6800000
# 6      33000000          4          678                  22500000
# 7      15000000         20          382                  13200000
# 8       2200000         20          782                   1300000
# 9       4300000         10          388                   3200000
# 10     11200000          2          547                   8100000
#
#     commercial_assets_value  luxury_assets_value  bank_asset_value loan_status
# 0                  17600000             22700000           8000000    Approved
# 1                   2200000              8800000           3300000    Rejected
# 2                   4500000             33300000          12800000    Rejected
# 3                   3300000             23300000           7900000    Rejected
# 4                   8200000             29400000           5000000    Rejected
# 5                   8300000             13700000           5100000    Rejected
# 6                  14800000             29200000           4300000    Approved
# 7                   5700000             11800000           6000000    Rejected
# 8                    800000              2800000            600000    Approved
# 9                   1400000              3300000           1600000    Rejected
# 10                  4700000              9500000           3100000    Approved

# %%
# X_train.shape
X_train.head()
# Out:
#       no_of_dependents     education self_employed  income_annum  loan_amount  \
# 497                  2  Not Graduate            No       8100000     24800000
# 1339                 5  Not Graduate           Yes       8800000     26600000
# 2607                 4  Not Graduate            No       5400000     12600000
# 628                  2  Not Graduate           Yes       4500000     12500000
# 3364                 1      Graduate           Yes       5200000     16300000
#
#       loan_term  cibil_score  residential_assets_value  \
# 497           6          307                    200000
# 1339         16          545                  19100000
# 2607         18          786                    300000
# 628          12          418                    400000
# 3364          6          524                  11000000
#
#       commercial_assets_value  luxury_assets_value  bank_asset_value
# 497                   4000000             31100000          10500000
# 1339                 16600000             30400000           7600000
# 2607                  2500000             21000000           6600000
# 628                   4300000             12400000           4300000
# 3364                  3400000             20700000           4600000

# %%
# X_test.shape
y_train.head()
# Out:
# 497     Rejected
# 1339    Rejected
# 2607    Approved
# 628     Rejected
# 3364    Rejected
# Name: loan_status, dtype: object

# %% [markdown]
# # Encoding

# %%
ohe = OneHotEncoder(drop='first')
# label_enc = LabelEncoder()

# %%
numerical = []
categorical = []

for col in X.columns:
    if X[col].dtype=='O':
        categorical.append(col)
    else:
        numerical.append(col)

# %%
categorical
# Out:
# ['education', 'self_employed']

# %%
X_train_enc = ohe.fit_transform(X_train[categorical])
X_test_enc = ohe.transform(X_test[categorical])

# %%
X_train_enc
# Out:
# <3201x2 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3218 stored elements in Compressed Sparse Row format>

# %%
X_train_enc.toarray()
# Out:
# array([[1., 0.],
#        [1., 1.],
#        [1., 0.],
#        ...,
#        [0., 1.],
#        [1., 1.],
#        [0., 1.]])

# %%
X_test_enc.toarray()
# Out:
# array([[0., 0.],
#        [1., 1.],
#        [0., 1.],
#        ...,
#        [1., 1.],
#        [1., 0.],
#        [1., 1.]])

# %%
X_train[numerical].head()
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 497                  2       8100000     24800000          6          307
# 1339                 5       8800000     26600000         16          545
# 2607                 4       5400000     12600000         18          786
# 628                  2       4500000     12500000         12          418
# 3364                 1       5200000     16300000          6          524
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 497                     200000                  4000000             31100000
# 1339                  19100000                 16600000             30400000
# 2607                    300000                  2500000             21000000
# 628                     400000                  4300000             12400000
# 3364                  11000000                  3400000             20700000
#
#       bank_asset_value
# 497           10500000
# 1339           7600000
# 2607           6600000
# 628            4300000
# 3364           4600000

# %%
X_train_enc_df = pd.DataFrame(data=X_test_enc.toarray(),columns=ohe.get_feature_names_out())
X_train_enc_df.head()
# Out:
#    education_Not Graduate  self_employed_Yes
# 0                     0.0                0.0
# 1                     1.0                1.0
# 2                     0.0                1.0
# 3                     0.0                0.0
# 4                     0.0                1.0

# %%
X_train_num = X_train[numerical].reset_index(drop=True)

# %%
X_train_num
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       8100000     24800000          6          307
# 1                    5       8800000     26600000         16          545
# 2                    4       5400000     12600000         18          786
# 3                    2       4500000     12500000         12          418
# 4                    1       5200000     16300000          6          524
# ...                ...           ...          ...        ...          ...
# 3196                 3       8300000     25900000          8          696
# 3197                 2       6900000     18200000         20          396
# 3198                 1       9000000     33500000          2          748
# 3199                 1       3200000      8100000         10          670
# 3200                 3       8000000     25300000          4          306
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                       200000                  4000000             31100000
# 1                     19100000                 16600000             30400000
# 2                       300000                  2500000             21000000
# 3                       400000                  4300000             12400000
# 4                     11000000                  3400000             20700000
# ...                        ...                      ...                  ...
# 3196                  14400000                 12200000             23500000
# 3197                  15600000                  4300000             22900000
# 3198                   7900000                  9800000             25700000
# 3199                   9100000                  3800000              9200000
# 3200                  22300000                  7300000             24400000
#
#       bank_asset_value
# 0             10500000
# 1              7600000
# 2              6600000
# 3              4300000
# 4              4600000
# ...                ...
# 3196           7100000
# 3197           5400000
# 3198          11500000
# 3199           1900000
# 3200           6600000
#
# [3201 rows x 9 columns]

# %%
X_train = pd.concat([X_train_num,X_train_enc_df],axis=1)

# %%
X_train
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       8100000     24800000          6          307
# 1                    5       8800000     26600000         16          545
# 2                    4       5400000     12600000         18          786
# 3                    2       4500000     12500000         12          418
# 4                    1       5200000     16300000          6          524
# ...                ...           ...          ...        ...          ...
# 3196                 3       8300000     25900000          8          696
# 3197                 2       6900000     18200000         20          396
# 3198                 1       9000000     33500000          2          748
# 3199                 1       3200000      8100000         10          670
# 3200                 3       8000000     25300000          4          306
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                       200000                  4000000             31100000
# 1                     19100000                 16600000             30400000
# 2                       300000                  2500000             21000000
# 3                       400000                  4300000             12400000
# 4                     11000000                  3400000             20700000
# ...                        ...                      ...                  ...
# 3196                  14400000                 12200000             23500000
# 3197                  15600000                  4300000             22900000
# 3198                   7900000                  9800000             25700000
# 3199                   9100000                  3800000              9200000
# 3200                  22300000                  7300000             24400000
#
#       bank_asset_value  education_Not Graduate  self_employed_Yes
# 0             10500000                     0.0                0.0
# 1              7600000                     1.0                1.0
# 2              6600000                     0.0                1.0
# 3              4300000                     0.0                0.0
# 4              4600000                     0.0                1.0
# ...                ...                     ...                ...
# 3196           7100000                     NaN                NaN
# 3197           5400000                     NaN                NaN
# 3198          11500000                     NaN                NaN
# 3199           1900000                     NaN                NaN
# 3200           6600000                     NaN                NaN
#
# [3201 rows x 11 columns]

# %%
X_train = pd.concat([X_train_num,X_train_enc_df],axis=1)

# %%
X_train
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    2       8100000     24800000          6          307
# 1                    5       8800000     26600000         16          545
# 2                    4       5400000     12600000         18          786
# 3                    2       4500000     12500000         12          418
# 4                    1       5200000     16300000          6          524
# ...                ...           ...          ...        ...          ...
# 3196                 3       8300000     25900000          8          696
# 3197                 2       6900000     18200000         20          396
# 3198                 1       9000000     33500000          2          748
# 3199                 1       3200000      8100000         10          670
# 3200                 3       8000000     25300000          4          306
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                       200000                  4000000             31100000
# 1                     19100000                 16600000             30400000
# 2                       300000                  2500000             21000000
# 3                       400000                  4300000             12400000
# 4                     11000000                  3400000             20700000
# ...                        ...                      ...                  ...
# 3196                  14400000                 12200000             23500000
# 3197                  15600000                  4300000             22900000
# 3198                   7900000                  9800000             25700000
# 3199                   9100000                  3800000              9200000
# 3200                  22300000                  7300000             24400000
#
#       bank_asset_value  education_Not Graduate  self_employed_Yes
# 0             10500000                     0.0                0.0
# 1              7600000                     1.0                1.0
# 2              6600000                     0.0                1.0
# 3              4300000                     0.0                0.0
# 4              4600000                     0.0                1.0
# ...                ...                     ...                ...
# 3196           7100000                     NaN                NaN
# 3197           5400000                     NaN                NaN
# 3198          11500000                     NaN                NaN
# 3199           1900000                     NaN                NaN
# 3200           6600000                     NaN                NaN
#
# [3201 rows x 11 columns]

# %% [markdown]
# #
# <h1 style='color:red'>07-08-2024

# %%
X_test_enc_df = pd.DataFrame(data=X_test_enc.toarray(),columns=ohe.get_feature_names_out())
X_test_enc_df.head()
# Out:
#    education_Not Graduate  self_employed_Yes
# 0                     0.0                0.0
# 1                     1.0                1.0
# 2                     0.0                1.0
# 3                     0.0                0.0
# 4                     0.0                1.0

# %%
X_test_num = X_test[numerical].reset_index(drop=True)

# %%
X_test_num.head()
# Out:
#    no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                 0       4200000     10300000         10          506
# 1                 3       6400000     15200000         14          467
# 2                 5       2300000      5600000          8          642
# 3                 2       8000000     31900000         16          806
# 4                 3       8000000     26300000         12          476
#
#    residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                   9300000                  4500000             12400000
# 1                  15500000                  9100000             18400000
# 2                   2600000                  1900000              8600000
# 3                  19900000                  1800000             23200000
# 4                  21700000                  6600000             16400000
#
#    bank_asset_value
# 0           6000000
# 1           3200000
# 2           2500000
# 3           5400000
# 4           9000000

# %%
# X_test_num.shape

# %%
# X_train_num.shape

# %%
X_test = pd.concat([X_test_num,X_test_enc_df],axis=1)
X_test.head()
# Out:
#    no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                 0       4200000     10300000         10          506
# 1                 3       6400000     15200000         14          467
# 2                 5       2300000      5600000          8          642
# 3                 2       8000000     31900000         16          806
# 4                 3       8000000     26300000         12          476
#
#    residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                   9300000                  4500000             12400000
# 1                  15500000                  9100000             18400000
# 2                   2600000                  1900000              8600000
# 3                  19900000                  1800000             23200000
# 4                  21700000                  6600000             16400000
#
#    bank_asset_value  education_Not Graduate  self_employed_Yes
# 0           6000000                     0.0                0.0
# 1           3200000                     1.0                1.0
# 2           2500000                     0.0                1.0
# 3           5400000                     0.0                0.0
# 4           9000000                     0.0                1.0

# %% [markdown]
# # Label Encoding

# %%
label_enc = LabelEncoder()

# %%
y_train_enc = label_enc.fit_transform(y_train)

# %%
y_train_enc[:2]
# Out:
# array([1, 1])

# %%
y_train.head(2)
# Out:
# 497     Rejected
# 1339    Rejected
# Name: loan_status, dtype: object

# %%
label_enc.classes_
# Out:
# array(['Approved', 'Rejected'], dtype=object)

# %%
label_enc.inverse_transform([1,0,0,0,1])
# Out:
# array(['Rejected', 'Approved', 'Approved', 'Approved', 'Rejected'],
#       dtype=object)

# %%
y_test_enc = label_enc.transform(y_test)

# %%
y_train_enc
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %% [markdown]
# ## Training the model
# <h1 style:

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train,y_train_enc)
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test_enc,y_pred)
print(accuracy)
# Out:
# 0.9719101123595506

# %%
# accuracy,percision,recall,confusion matrix, auc,pr-curve

# %%
y_pred
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
y_test = y_test.reset_index(drop=True)

# %%
X_test['y_actual'] = y_test

# %%
X_test
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    0       4200000     10300000         10          506
# 1                    3       6400000     15200000         14          467
# 2                    5       2300000      5600000          8          642
# 3                    2       8000000     31900000         16          806
# 4                    3       8000000     26300000         12          476
# ...                ...           ...          ...        ...          ...
# 1063                 2       3900000      9300000          8          591
# 1064                 3       7500000     26000000          2          342
# 1065                 4       3200000     12800000          8          638
# 1066                 3       9500000     20400000         14          376
# 1067                 2       2300000      9100000         20          610
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                      9300000                  4500000             12400000
# 1                     15500000                  9100000             18400000
# 2                      2600000                  1900000              8600000
# 3                     19900000                  1800000             23200000
# 4                     21700000                  6600000             16400000
# ...                        ...                      ...                  ...
# 1063                  10900000                  2700000              9600000
# 1064                  13900000                  1900000             26900000
# 1065                   4300000                  2600000              8000000
# 1066                   2300000                  6600000             25900000
# 1067                   3700000                   600000              7800000
#
#       bank_asset_value  education_Not Graduate  self_employed_Yes  y_actual
# 0              6000000                     0.0                0.0  Rejected
# 1              3200000                     1.0                1.0  Rejected
# 2              2500000                     0.0                1.0  Approved
# 3              5400000                     0.0                0.0  Approved
# 4              9000000                     0.0                1.0  Rejected
# ...                ...                     ...                ...       ...
# 1063           3300000                     1.0                1.0  Approved
# 1064          11200000                     1.0                1.0  Approved
# 1065           3800000                     1.0                1.0  Approved
# 1066           8400000                     1.0                0.0  Rejected
# 1067           3400000                     1.0                1.0  Approved
#
# [1068 rows x 12 columns]

# %%
y_pred_inv = label_enc.inverse_transform(y_pred)

# %%
y_pred_inv
# Out:
# array(['Rejected', 'Rejected', 'Approved', ..., 'Approved', 'Rejected',
#        'Approved'], dtype=object)

# %%
X_test['y_pred'] = y_pred_inv

# %%
X_test
# Out:
#       no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                    0       4200000     10300000         10          506
# 1                    3       6400000     15200000         14          467
# 2                    5       2300000      5600000          8          642
# 3                    2       8000000     31900000         16          806
# 4                    3       8000000     26300000         12          476
# ...                ...           ...          ...        ...          ...
# 1063                 2       3900000      9300000          8          591
# 1064                 3       7500000     26000000          2          342
# 1065                 4       3200000     12800000          8          638
# 1066                 3       9500000     20400000         14          376
# 1067                 2       2300000      9100000         20          610
#
#       residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                      9300000                  4500000             12400000
# 1                     15500000                  9100000             18400000
# 2                      2600000                  1900000              8600000
# 3                     19900000                  1800000             23200000
# 4                     21700000                  6600000             16400000
# ...                        ...                      ...                  ...
# 1063                  10900000                  2700000              9600000
# 1064                  13900000                  1900000             26900000
# 1065                   4300000                  2600000              8000000
# 1066                   2300000                  6600000             25900000
# 1067                   3700000                   600000              7800000
#
#       bank_asset_value  education_Not Graduate  self_employed_Yes  y_actual  \
# 0              6000000                     0.0                0.0  Rejected
# 1              3200000                     1.0                1.0  Rejected
# 2              2500000                     0.0                1.0  Approved
# 3              5400000                     0.0                0.0  Approved
# 4              9000000                     0.0                1.0  Rejected
# ...                ...                     ...                ...       ...
# 1063           3300000                     1.0                1.0  Approved
# 1064          11200000                     1.0                1.0  Approved
# 1065           3800000                     1.0                1.0  Approved
# 1066           8400000                     1.0                0.0  Rejected
# 1067           3400000                     1.0                1.0  Approved
#
#         y_pred
# 0     Rejected
# 1     Rejected
# 2     Approved
# 3     Approved
# 4     Rejected
# ...        ...
# 1063  Approved
# 1064  Rejected
# 1065  Approved
# 1066  Rejected
# 1067  Approved
#
# [1068 rows x 13 columns]

# %% [markdown]
# # Hyperparam Tuning

# %%
model
# Out:
# DecisionTreeClassifier()

# %%
model.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'random_state': None,
#  'splitter': 'best'}

# %%
params = {
         'criterion':['entropy', 'gini'],
         'max_depth': [3,4,5,6,7],
         'max_features': [3,4,5,6,7],
         'min_samples_leaf': [10,12,14,16],
         'min_samples_split': [20,22,24],
        }

# %%
2*5*5*4*3
# Out:
# 600

# %%
grid_search_cv = GridSearchCV(estimator=model,
                             param_grid=params,
                             cv=10)

# %%
grid_search_cv.fit(X_train,y_train)
# Out:
# C:\Users\Anoop Raj\anaconda3\Lib\site-packages\numpy\ma\core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['entropy', 'gini'],
#                          'max_depth': [3, 4, 5, 6, 7],
#                          'max_features': [3, 4, 5, 6, 7],
#                          'min_samples_leaf': [10, 12, 14, 16],
#                          'min_samples_split': [20, 22, 24]})

# %%
# np.arange(3,15)

# %%
grid_search_cv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 7,
#  'max_features': 7,
#  'min_samples_leaf': 12,
#  'min_samples_split': 22}

# %%
grid_search_cv.best_score_
# Out:
# 0.9746933411214952

# %%
y_train_enc
# Out:
# array([1, 1, 0, ..., 0, 0, 0])

# %%
best_model = grid_search_cv.best_estimator_

# %%
best_model.fit(X_train,y_train_enc)
# Out:
# DecisionTreeClassifier(max_depth=7, max_features=7, min_samples_leaf=10,
#                        min_samples_split=20)

# %%
X_test.head()
# Out:
#    no_of_dependents  income_annum  loan_amount  loan_term  cibil_score  \
# 0                 0       4200000     10300000         10          506
# 1                 3       6400000     15200000         14          467
# 2                 5       2300000      5600000          8          642
# 3                 2       8000000     31900000         16          806
# 4                 3       8000000     26300000         12          476
#
#    residential_assets_value  commercial_assets_value  luxury_assets_value  \
# 0                   9300000                  4500000             12400000
# 1                  15500000                  9100000             18400000
# 2                   2600000                  1900000              8600000
# 3                  19900000                  1800000             23200000
# 4                  21700000                  6600000             16400000
#
#    bank_asset_value  education_Not Graduate  self_employed_Yes  y_actual  \
# 0           6000000                     0.0                0.0  Rejected
# 1           3200000                     1.0                1.0  Rejected
# 2           2500000                     0.0                1.0  Approved
# 3           5400000                     0.0                0.0  Approved
# 4           9000000                     0.0                1.0  Rejected
#
#      y_pred
# 0  Rejected
# 1  Rejected
# 2  Approved
# 3  Approved
# 4  Rejected

# %%
best_pred = best_model.predict(X_test.iloc[:,:-2])

# %%
best_pred
# Out:
# array([1, 1, 0, ..., 0, 1, 0])

# %%
accuracy_score(y_test_enc,best_pred)
print(accuracy)
# Out:
# 0.9719101123595506

# %% [markdown]
# # Scalling Test
